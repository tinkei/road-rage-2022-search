# %% [markdown]
# # Tutorial: Batch Processing
#
# This tutorial explains how to use the batch processing script to solve CommonRoad planning problems in parallel. The configuration for batch processing is stored in `batch_processing_config.yaml`. Some of the parameters are explained as follows:
# * **input_path**: input directory of your intended CommonRoad scenarios.
# * **output_path**: output directory of CommonRoad solution files.
# * **overwrite**: whether the existing solution files should be overwritten.
# * **validate_solution**: check the validity of the solutions with the feasibility checker.
# * **num_worker_processes**: the number of parallel executions of motion planners.
#
# Parameters specified under the `default` block will be applied to all scenarios. If you wish to specify a different paramter for specific scenarios, simply insert a new block with the content of the `default` block copied, and overwrite parameters therein. This new block should be named after the ID of the sceanrio that you wish to aplly the parameters to. Related parameters are explained as follows:
# * **vehicle_model**: model of the vehicle, valid values: **PM, KS, ST and MB**. Refer to [Vehicle Models](https://gitlab.lrz.de/tum-cps/commonroad-vehicle-models/-/blob/master/vehicleModels_commonRoad.pdf) for more information.
# * **vehicle_type**: type of the vehicle, valid values: **FORD_ESCORT, BMW_320i and VW_VANAGON**.
# * **cost_function**: id of cost function. Refer to [Cost Functions](https://gitlab.lrz.de/tum-cps/commonroad-cost-functions/-/blob/master/costFunctions_commonRoad.pdf) for more information.
# * **planner**: the planner that is used to solve for solutions, possible values are: bfs, dfs, dls, ucs, gbfs, astar, student, student_example
# * **planning_problem_idx**: index of the planning problem. for cooperative scenarios: 0, 1, 2, ..., otherwise: 0
# * **max_tree_depth**: maximum depth of the search tree
# * **timeout**: timeout time for motion planner [s].
#
# Note: the paths can either be **relative** or **absolute**.
# To start the search with batch processing, you can either directly run `SMP/batch_processing/batch_processing_parallel.py` in IDEs (e.g. PyCharm) with `commonroad-search/` marked as sources root, or run the following script.

# %% [markdown]
# ## Parallel Batch Processing
# In parallel batch processing, the search are carried out on multiple threads simultaneously. This reduces the overall time required to test your algorithm on all the given scenarios. One drawback is that it is not very easy to debug your code with parallel batch processing.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

# add the folder containing batch processing script into python path
sys.path.append(os.path.join(os.getcwd(), "../../"))

from SMP.batch_processing.batch_processing_parallel import run_parallel_processing
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
run_parallel_processing()
# Out:
# Config file loaded and logger created.
# 18 scenarios skipped.
# ScenarioLoader Mode <DEFAULT>
# Run on all scenarios, except the skipped scenarios
# Number of scenarios: 500
# Automaton loaded for vehicle type: BMW_320i
# Motion planner: astar
# Number of parallel processes: 6
#
# ==================================================
# Scenario being processed:	         1
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         2
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         3
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         4
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         5
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         6
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for ARG_Carcarana-13_1_T-1 ...
# Generating GIF for ARG_Carcarana-5_2_T-1 ...
# Generating GIF for ARG_Carcarana-2_3_T-1 ...
# Generating GIF for ARG_Carcarana-7_1_T-1 ...
# Generating GIF for ARG_Carcarana-11_1_T-1 ...
# Generating GIF for ARG_Carcarana-3_3_T-1 ...
#
# ==================================================
# Scenario being processed:	         7
# Solution found:               	         1
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         8
# Solution found:               	         1
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         9
# Solution found:               	         2
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for ARG_Carcarana-9_2_T-1 ...
# Generating GIF for BEL_Aarschot-11_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        10
# Solution found:               	         3
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        11
# Solution found:               	         4
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Aarschot-1_2_T-1 ...
# Generating GIF for BEL_Aarschot-3_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        12
# Solution found:               	         5
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Aarschot-5_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        13
# Solution found:               	         6
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        14
# Solution found:               	         6
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Beringen-1_1_T-1 ...
# Process Process-1353:
# Process Process-1352:
# Something went wrong while processing scenario BEL_Beringen-1_1_T-1          ]
# Process Process-1354:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7d20668b298f> in <module>
# ----> 1 run_parallel_processing()
#
# ~/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/batch_processing_parallel.py in run_parallel_processing()
#      28         worker has completed its process.
#      29         """
# ---> 30         semaphore.acquire()
#      31         p = Process(target=process_scenario,
#      32                     args=(scenario_id, scenario_loader, configuration, def_automaton, result_dict, semaphore))
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 251, in saving
#     yield self
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 1141, in save
#     anim._draw_next_frame(d, blit=False)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 1176, in _draw_next_frame
#     self._draw_frame(framedata)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 1726, in _draw_frame
#     self._drawn_artists = self._func(framedata, *self._args)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/helper_functions.py", line 553, in animate_plot
#     scenario.draw(renderer, draw_params={'time_begin': frame})
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad/scenario/scenario.py", line 1041, in draw
#     renderer.draw_scenario(self, draw_params, call_stack)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad/visualization/mp_renderer.py", line 422, in draw_scenario
#     obj.lanelet_network.draw(self, draw_params, call_stack)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad/scenario/lanelet.py", line 1543, in draw
#     renderer.draw_lanelet_network(self, draw_params, call_stack)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad/visualization/mp_renderer.py", line 1190, in draw_lanelet_network
#     antialiased=antialiased))
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/collections.py", line 953, in __init__
#     super().__init__(**kwargs)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/collections.py", line 161, in __init__
#     artist.Artist.__init__(self)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/artist.py", line 100, in __init__
#     self._url = None
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 280, in process_scenario
#     logger=logger)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 163, in save_solution
#     output_path=output_path_gif)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/helper_functions.py", line 573, in save_gif2
#     anim.save(os.path.join(output_path, file_name), dpi=30, writer="imagemagick")
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 1145, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 253, in saving
#     self.finish()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 354, in finish
#     self.cleanup()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 391, in cleanup
#     self._proc.returncode, self._proc.args, out, err)
# subprocess.CalledProcessError: Command '['convert', '-size', '450x450', '-depth', '8', '-delay', '10.0', '-loop', '0', 'rgba:-', '../../outputs/gifs/BEL_Beringen-1_1_T-1.gif']' returned non-zero exit status 2.
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 280, in process_scenario
#     logger=logger)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 163, in save_solution
#     output_path=output_path_gif)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 1145, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/helper_functions.py", line 573, in save_gif2
#     anim.save(os.path.join(output_path, file_name), dpi=30, writer="imagemagick")
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 280, in process_scenario
#     logger=logger)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/contextlib.py", line 119, in __exit__
#     next(self.gen)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 169, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 253, in saving
#     self.finish()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/solution_checker.py", line 319, in valid_solution
#     not boundary_collision(scenario, planning_problem_set, solution),
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 354, in finish
#     self.cleanup()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 376, in cleanup
#     out, err = self._proc.communicate()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/subprocess.py", line 964, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/subprocess.py", line 1715, in _communicate
#     ready = selector.select(timeout)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 280, in process_scenario
#     logger=logger)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 169, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
# KeyboardInterrupt
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/solution_checker.py", line 322, in valid_solution
#     results = solution_feasible(solution, scenario.dt, planning_problem_set)
# Process Process-1355:
# Process Process-1356:
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/solution_checker.py", line 177, in boundary_collision
#     collision_checker = _construct_boundary_checker(scenario)
# Traceback (most recent call last):
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/solution_checker.py", line 72, in _construct_boundary_checker
#     boundary = construction.construct(scenario, build)
# Traceback (most recent call last):
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/solution_checker.py", line 137, in solution_feasible
#     feasible, inputs = _check_trajectory_feasibility(pp_solution, vehicle_dynamics, dt)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/solution_checker.py", line 107, in _check_trajectory_feasibility
#     vehicle_dynamics, dt)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 280, in process_scenario
#     logger=logger)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/boundary/construction.py", line 140, in construct
#     build(build_order)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/boundary/construction.py", line 87, in build
#     options.get(order)()
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 163, in save_solution
#     output_path=output_path_gif)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/helper_functions.py", line 573, in save_gif2
#     anim.save(os.path.join(output_path, file_name), dpi=30, writer="imagemagick")
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 1145, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/contextlib.py", line 119, in __exit__
#     next(self.gen)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 253, in saving
#     self.finish()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 354, in finish
#     self.cleanup()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 376, in cleanup
#     out, err = self._proc.communicate()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/feasibility_checker.py", line 319, in trajectory_feasibility
#     criteria, ftol, e, d, maxiter, disp)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/subprocess.py", line 964, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/feasibility_checker.py", line 233, in state_transition_feasibility
#     method='SLSQP', bounds=vehicle_dynamics.input_bounds).x
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/subprocess.py", line 1715, in _communicate
#     ready = selector.select(timeout)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 626, in minimize
#     constraints, callback=callback, **options)
# KeyboardInterrupt
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/scipy/optimize/slsqp.py", line 422, in _minimize_slsqp
#     fx = sf.fun(x)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/boundary/construction.py", line 75, in <lambda>
#     "triangulation": lambda: help_triangulate(params),
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 280, in process_scenario
#     logger=logger)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/boundary/construction.py", line 60, in help_triangulate
#     triangle_builder.triangulate(bounds, hull_points, road, triangulation, params)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py", line 182, in fun
#     self._update_fun()
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 163, in save_solution
#     output_path=output_path_gif)
#   File "/home/edmond/Softwares/commonroad/commonroad-search-cps/tutorials/4_batch_processing/../../SMP/batch_processing/helper_functions.py", line 573, in save_gif2
#     anim.save(os.path.join(output_path, file_name), dpi=30, writer="imagemagick")
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/boundary/triangle_builder.py", line 142, in triangulate
#     segset = set([map_segment(entry, vertices) for entry in segset if len(entry) == 2])
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 1145, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/boundary/triangle_builder.py", line 142, in <listcomp>
#     segset = set([map_segment(entry, vertices) for entry in segset if len(entry) == 2])
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/boundary/triangle_builder.py", line 137, in map_segment
#     v2_index = [i for i, entry in enumerate(vertices) if entry == v2][0]
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/boundary/triangle_builder.py", line 137, in <listcomp>
#     v2_index = [i for i, entry in enumerate(vertices) if entry == v2][0]
# KeyboardInterrupt
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py", line 166, in _update_fun
#     self._update_fun_impl()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py", line 73, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/contextlib.py", line 119, in __exit__
#     next(self.gen)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 253, in saving
#     self.finish()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 354, in finish
#     self.cleanup()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/matplotlib/animation.py", line 376, in cleanup
#     out, err = self._proc.communicate()
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/subprocess.py", line 964, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/subprocess.py", line 1715, in _communicate
#     ready = selector.select(timeout)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py", line 70, in fun_wrapped
#     return fun(x, *args)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/feasibility_checker.py", line 109, in position_orientation_objective
#     x1_sim = vehicle_dynamics.forward_simulation(x0_adjusted, u, dt, throw=False)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/commonroad_drivability_checker-2021.1-py3.7-linux-x86_64.egg/commonroad_dc/feasibility/vehicle_dynamics.py", line 217, in forward_simulation
#     x0, x1 = odeint(self.dynamics, x, [0.0, dt], args=(u,), tfirst=True)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/site-packages/scipy/integrate/odepack.py", line 240, in odeint
#     y0 = copy(y0)
#   File "/home/edmond/Softwares/others/anaconda3/envs/cr37/lib/python3.7/copy.py", line 74, in copy
#     copier = _copy_dispatch.get(cls)
# KeyboardInterrupt

# %% [markdown]
# ## Sequential Batch Processing
#
# Alternatively, one can use the `SMP/batch_processing/batch_processing_sequential.py` script to carry out the search sequentially on a single thread. This is a more user-friendly approach if you wish you debug your code in IDES (e.g. creating breakpoints in PyCharm) but still have it run against multiple scenarios.

# %%
from SMP.batch_processing.batch_processing_sequential import run_sequential_processing
run_sequential_processing()
# Out:
# Config file loaded and logger created.
# 18 scenarios skipped.
# ScenarioLoader Mode <DEFAULT>
# Run on all scenarios, except the skipped scenarios
# Number of scenarios: 500
# Automaton loaded for vehicle type: BMW_320i
# Motion planner: astar
# Generating GIF for ARG_Carcarana-11_1_T-1 ...
#
# ==================================================
# Scenario being processed:	         1
# Solution found:               	         1
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for ARG_Carcarana-13_1_T-1 ...
#
# ==================================================
# Scenario being processed:	         2
# Solution found:               	         2
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for ARG_Carcarana-2_3_T-1 ...
#
# ==================================================
# Scenario being processed:	         3
# Solution found:               	         3
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for ARG_Carcarana-3_3_T-1 ...
#
# ==================================================
# Scenario being processed:	         4
# Solution found:               	         4
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for ARG_Carcarana-5_2_T-1 ...
#
# ==================================================
# Scenario being processed:	         5
# Solution found:               	         5
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for ARG_Carcarana-7_1_T-1 ...
#
# ==================================================
# Scenario being processed:	         6
# Solution found:               	         6
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         7
# Solution found:               	         6
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for ARG_Carcarana-9_2_T-1 ...
#
# ==================================================
# Scenario being processed:	         8
# Solution found:               	         7
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Aarschot-11_1_T-1 ...
#
# ==================================================
# Scenario being processed:	         9
# Solution found:               	         8
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Aarschot-1_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        10
# Solution found:               	         9
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Aarschot-3_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        11
# Solution found:               	        10
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Aarschot-5_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        12
# Solution found:               	        11
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        13
# Solution found:               	        11
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Beringen-1_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        14
# Solution found:               	        12
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Beringen-8_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        15
# Solution found:               	        13
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Nivelles-10_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        16
# Solution found:               	        14
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Nivelles-16_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        17
# Solution found:               	        15
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Nivelles-18_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        18
# Solution found:               	        16
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Nivelles-19_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        19
# Solution found:               	        17
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Nivelles-1_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        20
# Solution found:               	        18
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Nivelles-20_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        21
# Solution found:               	        19
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Nivelles-3_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        22
# Solution found:               	        20
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Nivelles-4_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        23
# Solution found:               	        21
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Nivelles-9_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        24
# Solution found:               	        22
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Putte-10_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        25
# Solution found:               	        23
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Putte-11_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        26
# Solution found:               	        24
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        27
# Solution found:               	        24
# Solution found but invalid:   	         0
# Solution not found:           	         3
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        28
# Solution found:               	        24
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Putte-2_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        29
# Solution found:               	        25
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Putte-3_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        30
# Solution found:               	        26
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Putte-4_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        31
# Solution found:               	        27
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Putte-6_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        32
# Solution found:               	        28
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Wervik-1_4_T-1 ...
#
# ==================================================
# Scenario being processed:	        33
# Solution found:               	        29
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Wervik-2_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        34
# Solution found:               	        30
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Wervik-4_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        35
# Solution found:               	        31
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zaventem-1_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        36
# Solution found:               	        32
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zaventem-3_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        37
# Solution found:               	        33
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zaventem-4_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        38
# Solution found:               	        34
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zaventem-5_3_T-1 ...
#
# ==================================================
# Scenario being processed:	        39
# Solution found:               	        35
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zwevegem-2_3_T-1 ...
#
# ==================================================
# Scenario being processed:	        40
# Solution found:               	        36
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zwevegem-3_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        41
# Solution found:               	        37
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zwevegem-5_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        42
# Solution found:               	        38
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zwevegem-7_2_T-1 ...
# ==================================================
# Scenario being processed:	        43
# Solution found:               	        39
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zwevegem-8_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        44
# Solution found:               	        40
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for BEL_Zwevegem-8_4_T-1 ...
#
# ==================================================
# Scenario being processed:	        45
# Solution found:               	        41
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_Backnang-1_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        46
# Solution found:               	        42
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_Backnang-4_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        47
# Solution found:               	        43
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_Backnang-5_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        48
# Solution found:               	        44
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_Backnang-6_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        49
# Solution found:               	        45
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_Backnang-9_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        50
# Solution found:               	        46
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_BadEssen-3_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        51
# Solution found:               	        47
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_BadEssen-4_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        52
# Solution found:               	        48
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_BadWaldsee-1_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        53
# Solution found:               	        49
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_BadWaldsee-4_2_T-1 ...
#
# ==================================================
# Scenario being processed:	        54
# Solution found:               	        50
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_BadWaldsee-4_5_T-1 ...
#
# ==================================================
# Scenario being processed:	        55
# Solution found:               	        51
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_Bilderstoeckchen-2_3_T-1 ...
#
# ==================================================
# Scenario being processed:	        56
# Solution found:               	        52
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# Generating GIF for DEU_Bilderstoeckchen-4_1_T-1 ...
#
# ==================================================
# Scenario being processed:	        57
# Solution found:               	        53
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
